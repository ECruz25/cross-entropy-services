# %%
import pandas as pd
import numpy
from sklearn.model_selection import train_test_split, cross_val_predict,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn import metrics
import datetime

# %%
lemonade_sales = pd.read_csv('./test/Lemonade.csv')
lemonade_sales.head()
# Out:
#        Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  1/1/2017     Sunday         27.0      2.00      15    0.3     10
# 1  2/1/2017     Monday         28.9      1.33      15    0.3     13
# 2  3/1/2017    Tuesday         34.5      1.33      27    0.3     15
# 3  4/1/2017  Wednesday         44.1      1.05      28    0.3     17
# 4  5/1/2017   Thursday         42.4      1.00      33    0.3     18

# %%
dependent_variable = 'Sales'
independent_variables = ['Day', 'Temperature', 'Price']

# %%
y = lemonade_sales[dependent_variable]
X = lemonade_sales[independent_variables]
X = pd.get_dummies(data=X, prefix=['Day'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
linear_regression = LinearRegression().fit(X_train, y_train)

# %%
## Asumiendo que el usuario viene y manda nueva informacion
prediction_request = {
    'day': 'Sunday',
    'temperature': 51,
    'rainfall': 2,
    'flyers': 30,
    'price': 0.5
}

# %%
prediction_request
# Out:
# {'day': 'Sunday', 'temperature': 51, 'rainfall': 2, 'flyers': 30, 'price': 0.5}

# %%
from datetime import date
import calendar
for date in pd.date_range(end = pd.datetime.today(), periods = 30).to_pydatetime().tolist():
    print(calendar.day_name[date.weekday()])
# Out:
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# ...

# %%
pd.date_range(end = pd.datetime.today(), periods = 100).to_pydatetime().tolist()
# Out:
# [datetime.datetime(2019, 7, 26, 12, 12, 51, 554648),
#  datetime.datetime(2019, 7, 27, 12, 12, 51, 554648),
#  datetime.datetime(2019, 7, 28, 12, 12, 51, 554648),
#  datetime.datetime(2019, 7, 29, 12, 12, 51, 554648),
#  datetime.datetime(2019, 7, 30, 12, 12, 51, 554648),
#  datetime.datetime(2019, 7, 31, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 1, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 2, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 3, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 4, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 5, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 6, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 7, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 8, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 9, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 10, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 11, 12, 12, 51, 554648),
#  datetime.datetime(2019, 8, 12, 12, 12, 51, 554648),
# ...
